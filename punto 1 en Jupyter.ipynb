# %%
# Out:
#   sepal_length_in_cm          sepal_width_in_cm  petal_length_in_cm  \
# 0              fecha  codigo_departamento_indec  id_provincia_indec
# 1         2014-01-01                       2000                   2
# 2         2014-01-01                       2000                   2
# 3         2014-01-01                       2000                   2
# 4         2014-01-01                       2000                   2
#
#   petal_width_in_cm    class
# 0             clae2  puestos
# 1                 1     5448
# 2                 2      114
# 3                 3      571
# 4                 5      -99

# %%
##DESAFIO 1
import pandas as pd
#df = pd.read_csv("puestos_depto_priv_por_clae22.csv")
df = pd.read_csv("https://raw.githubusercontent.com/diegofernandodelgado/AllData/main/puestos_depto_priv_por_clae22.csv")
#print(df)

df_puestos = df.iloc[:, [4, 1]]
df_empleados = df.iloc[:, [2, 4]]

df_temp = pd.DataFrame(df['codigo_departamento_indec'].unique())
df_departamentos= df_temp.rename(columns={0:'codigo_departamento_indec'})

print(df_departamentos)
print("-------------------------------------------------------------")
print(df_puestos)
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(df_empleados)
# Out:
#     codigo_departamento_indec
# 0                        2000
# 1                        6007
# 2                        6014
# 3                        6021
# 4                        6028
# 5                        6035
# 6                        6042
# 7                        6049
# 8                        6056
# 9                        6063
# 10                       6070
# 11                       6077
# 12                       6084
# 13                       6091
# -------------------------------------------------------------
#      puestos  codigo_departamento_indec
# 0       5448                       2000
# 1        114                       2000
# 2        571                       2000
# 3        -99                       2000
# 4       2701                       2000
# ..       ...                        ...
# 995      439                       6091
# 996      374                       6091
# 997       24                       6091
# ...

# %%
# !pip install azure-storage-blob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 392.2/392.2 kB 4.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 194.3/194.3 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 41.7/41.7 kB 2.1 MB/s eta 0:00:00
# ...

# %%
##DESAFIO 2
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient


local_file_path01 = 'departamentos.csv'
local_file_path02 = 'puestos.csv'
local_file_path03 = 'empleados.csv'
df_departamentos.to_csv(local_file_path01, index=False)
df_puestos.to_csv(local_file_path02, index=False)
df_empleados.to_csv(local_file_path03, index=False)

#  Azure Blob Storage
account_name = 'diego.delgado@globalmvm.com'
account_key = 'puhotebrop22*'
container_name = 'FileTest2'
blob_name = 'departamentos.csv'

#BlobServiceClient
blob_service_client = BlobServiceClient(account_url=f"https://{account_name}.blob.core.windows.net", credential=account_key)

#BlobClient
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Subir archivo Departamento
with open(local_file_path01, "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

blob_name = 'puestos.csv'
#BlobClient
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Subir archivo puestos
with open(local_file_path02, "rb") as data:
    blob_client.upload_blob(data, overwrite=True)


blob_name = 'empleados.csv'
#BlobClient
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Subir archivo empleados
with open(local_file_path03, "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

print(f"Archivo subido a https://{account_name}.blob.core.windows.net/{container_name}/{blob_name}")
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# Cell In[162], line 26
#      24 # Subir archivo Departamento
#      25 with open(local_file_path01, "rb") as data:
# ---> 26     blob_client.upload_blob(data, overwrite=True)
#      28 blob_name = 'puestos.csv'
#      29 #BlobClient
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\tracing\decorator.py:94, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      92 span_impl_type = settings.tracing_implementation()
#      93 if span_impl_type is None:
# ---> 94     return func(*args, **kwargs)
#      96 # Merge span is parameter is set, but only if no explicit parent are passed
#      97 if merge_span and not passed_in_parent:
#
# ...

# %%
# Instalar bibliotecas necesarias
# !pip install pymongo pandas

from pymongo import MongoClient

#conexión BD CLOUD
client = MongoClient("mongodb://diegodelgado:Cc16@cloud.mongodb.com/v2/63ec2af8db9915259b807109#/clusters/)
db = client.your_database
collection = db.your_collection

# DataFrame TO diccionario
data_dep = df_departamentos.to_dict("records")
data_pue = df_puestos.to_dict("records")
data_emp = df_empleados.to_dict("records")

# Transferir a MongoDB
collection.insert_many(data_dep)
collection.insert_many(data_pue)
collection.insert_many(data_emp)
# Out:
#   Cell In[164], line 7
#     client = MongoClient("mongodb://diegodelgado:Cc16@cloud.mongodb.com/v2/63ec2af8db9915259b807109#/clusters/)
#                          ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
from typing import Union

from fastapi import FastAPI

app = FastAPI()


@app.get("/")
def read_root():
    return {"Hello": "World"}


@app.get("/items/{item_id}")
def read_item(item_id: int, q: Union[str, None] = None):
    return {"item_id": item_id, "q": q}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[166], line 3
#       1 from typing import Union
# ----> 3 from fastapi import FastAPI
#       5 app = FastAPI()
#       8 @app.get("/")
#       9 def read_root():
#
# ModuleNotFoundError: No module named 'fastapi'
